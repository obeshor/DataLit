# %% [markdown]
# <a href="https://colab.research.google.com/github/obeshor/DataLit/blob/master/1-Data%20Collection/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 3.9MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My Twitter API Authentication Variables
consumer_key = ' '
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Tensorflow', count=300)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @KirkDBorne: #DataEngineering 1, 2, 3...\n(...
# 1  Going to O’Reilly AI? Then join us for some “S...
# 2                  もうダメだ\nTensorflow わからんし、変更したやつ動かん
# 3  RT @machine_ml: RT @ServerlessFan: RT @neptanu...
# 4  RT @africatechup: #AfricaTechupTour #Abidjan\n...
# 5  RT @nacho_usa: Great article on how (and why) ...
# 6  RT @gp_pulipaka: #MachineLearning Prediction o...
# 7  RT @gp_pulipaka: Deep Learning as Optimal Cont...
# 8  RT @TensorFlow: We just added a new tutorial t...
# 9  RT @gp_pulipaka: Study Shows Many Senior Manag...
# 2019-04-12 16:01:38

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @KirkDBorne: #DataEngineering 1, 2, 3...\n(...
# 1   Going to O’Reilly AI? Then join us for some “S...
# 2                   もうダメだ\nTensorflow わからんし、変更したやつ動かん
# 3   RT @machine_ml: RT @ServerlessFan: RT @neptanu...
# 4   RT @africatechup: #AfricaTechupTour #Abidjan\n...
# 5   RT @nacho_usa: Great article on how (and why) ...
# 6   RT @gp_pulipaka: #MachineLearning Prediction o...
# 7   RT @gp_pulipaka: Deep Learning as Optimal Cont...
# 8   RT @TensorFlow: We just added a new tutorial t...
# 9   RT @gp_pulipaka: Study Shows Many Senior Manag...
# 10  RT @DynamicWebPaige: "If you’re in industry, @...
# 11  RT @TensorFlow: We just added a new tutorial t...
# 12  RT @gp_pulipaka: Ten Random Useful Things in R...
# 13  RT @gp_pulipaka: #Programming Languages: Don't...
# 14  RT @gp_pulipaka: #MachineLearning Prediction o...
# 15  RT @gp_pulipaka: Dengue Fever Prediction using...
# ...

# %%
tweets=pd.DataFrame()

tweets["neg"]=[(sid.polarity_scores(i)['neg']) for i in data['Tweets']]
tweets["neu"]=[(sid.polarity_scores(i)['neu']) for i in data['Tweets']]
tweets["pos"]=[(sid.polarity_scores(i)['pos']) for i in data['Tweets']]
tweets["compound"]=[(sid.polarity_scores(i)['compound']) for i in data['Tweets']]

pos=0
neg=0
neu=0

##print(tweets["compound"])
for compound in tweets["compound"]:
  if compound >= 0.5:
    pos+=1
  elif compound <= -0.5:
    neg+=1
  else:
    neu+=1

# %%
import matplotlib.pyplot as plt

labels = 'positive', 'neutral', 'negative'
sections = [pos, neu, neg]
colors = ['c', 'g', 'y']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0, 0.1, 0),
        autopct = '%1.2f%%')

plt.axis('equal') # Try commenting this out.
plt.title('Twitter Sentiment Analysis of "Tensorflow"')
plt.show()
