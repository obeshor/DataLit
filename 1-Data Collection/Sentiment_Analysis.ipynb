# %% [markdown]
# <a href="https://colab.research.google.com/github/obeshor/DataLit/blob/master/1-Data%20Collection/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.23.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.16.2)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.5.0->pandas) (1.11.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2019.3.9)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 6.2MB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My Twitter API Authentication Variables
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Paul Biya', count=1000)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @GuardianNigeria: Hopefully, the dictators ...
# 1  RT @lucienbodo: Bonjour M. @PR_Paul_BIYA \nLa ...
# 2  En tout cas ça ne surprend plus venant de quel...
# 3  @France24_fr @mauritaniefoot @PR_Paul_BIYA alo...
# 4  @goal Dictatorial Paul Biya of Cameroon lions ...
# 5  RT @kingMannie: Cameroon  is at war and the wo...
# 6  RT @John_Chichester: So sad. An entire country...
# 7  RT @GuardianNigeria: Hopefully, the dictators ...
# 8  @nchifong @PR_Paul_BIYA @Elysee @FRauCameroun ...
# 9  RT @John_Chichester: So sad. An entire country...
# 2019-04-12 21:33:12

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @GuardianNigeria: Hopefully, the dictators ...
# 1   RT @lucienbodo: Bonjour M. @PR_Paul_BIYA \nLa ...
# 2   En tout cas ça ne surprend plus venant de quel...
# 3   @France24_fr @mauritaniefoot @PR_Paul_BIYA alo...
# 4   @goal Dictatorial Paul Biya of Cameroon lions ...
# 5   RT @kingMannie: Cameroon  is at war and the wo...
# 6   RT @John_Chichester: So sad. An entire country...
# 7   RT @GuardianNigeria: Hopefully, the dictators ...
# 8   @nchifong @PR_Paul_BIYA @Elysee @FRauCameroun ...
# 9   RT @John_Chichester: So sad. An entire country...
# 10  @IAnjiebright @dibussi The criminal government...
# 11  RT @AllezLesLions: « Je tiens à remercier part...
# 12  @iam_henrytwist @adeyanjudeji Yes, protesters ...
# 13  RT @France24_fr: #CAN2019 : "La #CAN, cela fai...
# 14  Ahmad le président de la CAF remercie les prés...
# 15  @fredaxelebe @HonneurFidelite @PR_Paul_BIYA Ri...
# 16  RT @France24_fr: #CAN2019 : "La #CAN, cela fai...
# 17  RT @ketsiabanana: Paul Biya a demandé à la @ca...
# 18  RT @GuardianNigeria: Hopefully, the dictators ...
# 19  RT @France24_fr: #CAN2019 : "La #CAN, cela fai...
# 20  #CAN2019 : "La #CAN, cela faisait 1 an qu'ils ...
# 21  RT @kingMannie: Cameroon  is at war and the wo...
# 22  RT @AllezLesLions: « Je tiens à remercier part...
# 23  Paul Biya a demandé à la @caf_online_FR de ne ...
# 24  Cameroon  is at war and the world is mute. Tho...
# 25  RT @GuardianNigeria: Hopefully, the dictators ...
# 26  RT @GuardianNigeria: Hopefully, the dictators ...
# 27  RT @AsongDr: Tibor Nagy @AsstSecStateAF disapp...
# 28  @PR_Paul_BIYA @Elysee @FRauCameroun @G_Thibaul...
# 29  Waiting for Paul Biya to congratulate the Suda...
# ..                                                ...
# 36             @mayorofwarri Paul biya of Cameroon 🇨🇲
# 37  RT @GuardianNigeria: Hopefully, the dictators ...
# 38  A Cameroonian @atiku has no part in our electi...
# 39  RT @AllezLesLions: « Je tiens à remercier part...
# 40  RT @GuardianNigeria: Hopefully, the dictators ...
# 41  RT @AllezLesLions: « Je tiens à remercier part...
# 42  RT @GuardianNigeria: Hopefully, the dictators ...
# 43  Hopefully, the dictators of Africa like Camero...
# 44  Hopefully, the dictators of Africa like Camero...
# 45  RT @GuardianNigeria: Hopefully, the dictators ...
# 46  If only @atiku lobbied against Paul Biya's pre...
# 47  RT @MichaelSchfer71: #Sudan Ein #Diktator weni...
# 48  @DAVIDAWILO This afcon draw is a farce from th...
# 49  RT @NdegeSerikal: Africa has the longest servi...
# 50  @thecableng @segilolaa @OfficialPDPNig Atiku w...
# 51  RT @GuardianNigeria: Hopefully, the dictators ...
# 52  « Je tiens à remercier particulièrement le Pré...
# 53  Cameron president Paul Biya. https://t.co/UKzg...
# 54  RT @AllezLesLions: « Je tiens à remercier part...
# 55  Paul Biya du Cameroun attendu à Genève : la di...
# 56  RT @NationalTelegr2: Paul Biya Must Be Shocked...
# 57  RT @AllezLesLions: « Je tiens à remercier part...
# 58  @PR_Paul_BIYA @Elysee @FRauCameroun @G_Thibaul...
# 59  RT @AllezLesLions: « Je tiens à remercier part...
# 60  RT @AllezLesLions: « Je tiens à remercier part...
# 61  RT @AllezLesLions: « Je tiens à remercier part...
# 62  @PR_Paul_BIYA @Elysee @FRauCameroun @G_Thibaul...
# 63                               @Kwanza_TV Paul biya
# 64  RT @GuardianNigeria: Hopefully, the dictators ...
# 65  RT @AllezLesLions: « Je tiens à remercier part...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.067, 'neu': 0.933, 'pos': 0.0, 'comp...
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   {'neg': 0.165, 'neu': 0.72, 'pos': 0.114, 'com...
# 5   {'neg': 0.159, 'neu': 0.778, 'pos': 0.063, 'co...
# 6   {'neg': 0.114, 'neu': 0.569, 'pos': 0.318, 'co...
# 7   {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9   {'neg': 0.114, 'neu': 0.569, 'pos': 0.318, 'co...
# 10  {'neg': 0.185, 'neu': 0.815, 'pos': 0.0, 'comp...
# 11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 12  {'neg': 0.234, 'neu': 0.642, 'pos': 0.124, 'co...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15  {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'comp...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 21  {'neg': 0.159, 'neu': 0.778, 'pos': 0.063, 'co...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 24  {'neg': 0.244, 'neu': 0.667, 'pos': 0.089, 'co...
# 25  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 26  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 27  {'neg': 0.133, 'neu': 0.769, 'pos': 0.097, 'co...
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29  {'neg': 0.094, 'neu': 0.604, 'pos': 0.301, 'co...
# ..                                                ...
# 36  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 37  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 38  {'neg': 0.099, 'neu': 0.901, 'pos': 0.0, 'comp...
# 39  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 40  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 41  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 42  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 43  {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'comp...
# 44  {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'comp...
# 45  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 47  {'neg': 0.187, 'neu': 0.813, 'pos': 0.0, 'comp...
# 48  {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compou...
# 49  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 50  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 51  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 52  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 53  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 54  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 55  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 56  {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'comp...
# 57  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 58  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 59  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 60  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 61  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 62  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 63  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 64  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 65  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [66 rows x 2 columns]

# %%
tweets=pd.DataFrame()

tweets["neg"]=[(sid.polarity_scores(i)['neg']) for i in data['Tweets']]
tweets["neu"]=[(sid.polarity_scores(i)['neu']) for i in data['Tweets']]
tweets["pos"]=[(sid.polarity_scores(i)['pos']) for i in data['Tweets']]
tweets["compound"]=[(sid.polarity_scores(i)['compound']) for i in data['Tweets']]

pos=0
neg=0
neu=0

##print(tweets["compound"])
for compound in tweets["compound"]:
  if compound >= 0.5:
    pos+=1
  elif compound <= -0.5:
    neg+=1
  else:
    neu+=1

# %%
import matplotlib.pyplot as plt

labels = 'positive', 'neutral', 'negative'
sections = [pos, neu, neg]
colors = ['g', 'c', 'r']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0, 0.1, 0),
        autopct = '%1.2f%%')

plt.axis('equal') # Try commenting this out.
plt.title('Twitter Sentiment Analysis of "Paul Biya"')
plt.show()
